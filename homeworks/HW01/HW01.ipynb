# %% [markdown]
# 1. Импорт библиотеки NumPy с общепринятым сокращением.
# 2. Примеры создания массивов:
#    - из обычных списков;
#    - с использованием функций `zeros`, `ones`, `arange` или аналогичных.
# 3. Демонстрация атрибутов:
#    - вывод формы (shape) и типа данных (dtype) для одного из массивов.
# 4. Примеры индексирования и срезов:
#    - получение отдельного элемента;
#    - извлечение подмассива с помощью среза.
# 5. Примеры векторных операций и базовых статистик:
#    - поэлементное сложение или умножение массивов;
#    - вычисление средней величины (`mean`) или другой простой статистики.

# %%
# Импорт библиотеки NumPy
import numpy as np

# Создание одномерного массива из обычного списка
rand_list = [0, "A", "B", 3, 4, 5]
arr_from_list = np.array(num_list)

# Создание одномерного массива с помощью встроенных в np методов
# С помощью метода arange объявляется одномерный массив со значениями от 0 до 5 с шагом 2
arange_arr = np.arange(0, 5, 2)
# С помощью метода zeros и ones задается одномерный массив 0 и 1 определенной длины
zer_arr = np.zeros(5)
ones_arr = np.ones(5)

# Демонстрация атрибутов формы и типа данных
shape_arr_from_list = arr_from_list.shape
dtype_arr_from_list = arr_from_list.dtype

# Индексирование и срезы
element_fr_zer = zer_arr[2]
new_arr = zer_arr[1:3]

# Поэлементное сложение и умножение массивов
sum_arr = new_arr + np.ones(2)
mult_arr = new_arr * new_arr

# Вычисление средней величины
mean_arange_arr = arange_arr.mean()

# Вывод результатов
print('Исходный массив:', rand_list)
print('Массив от 0 до 5 с шагом 2:', arange_arr)
print('Массив 5 нулей:', zer_arr)
print('Массив 5 единиц:', ones_arr)
print('Форма массива:', shape_arr_from_list)
print('Тип данных массива:', dtype_arr_from_list)
print('2 элемент массива:', element_fr_zer)
print('Срез массива:', new_arr)
print('Сумма поэлементо:', sum_arr)
print('Умножение поэлементно:', mult_arr)
print('Среднее значение:', mean_arange_arr)
# Out:
# Исходный массив: [0, 'A', 'B', 3, 4, 5]
# Массив от 0 до 5 с шагом 2: [0 2 4]
# Массив 5 нулей: [0. 0. 0. 0. 0.]
# Массив 5 единиц: [1. 1. 1. 1. 1.]
# Форма массива: (6,)
# Тип данных массива: <U21
# 2 элемент массива: 0.0
# Срез массива: [0. 0.]
# Сумма поэлементо: [1. 1.]
# Умножение поэлементно: [0. 0.]
# Среднее значение: 2.0
